# %% [markdown]
# # Assignment22 Solutions

# %% [markdown]
#     1. What is the result of the code, and explain?
#
#
#     >>> X = 'iNeuron'
#     >>> def func():
#     print(X)
#     >>> func()
#
#
#
# ###  sol--> This function print a "iNeuron" because when valriable is not aviable in func local scope then its looking for a global variable so in this program X is not aviable in local scope but ist aviable globally and its holds a iNeuron that why this func call prints a "iNeuron".
#
#
#
#
#     2. What is the result of the code, and explain?
#     >>> X = 'iNeuron'
#     >>> def func():
#     X = 'NI!'
#     >>> func()
#     >>> print(X)
#
#
#
#
# ### sol--> This will we print a "iNeuron" because be print a X variable without a func call so it did not go for a func local variable it can print a global variable value.
#
#
#
#
#
#     3. What does this code print, and why?
#     >>> X = 'iNeuron'
#     >>> def func():
#     X = 'NI'
#     print(X)
#     >>> func()
#     >>> print(X)
#
#
#
#
# ### sol--> outupt-(NI , iNeuron) First it will print a NI because when be call a func() it will go inside a function there is an func() local variable X="NI" then this function print that valriable then we come out that fuction and after than our program have print(X) so it will be print a Global X value which is "iNeuron"
#
#
#
#
#     4. What output does this code produce? Why?
#     >>> X = 'iNeuron'
#     >>> def func():
#     global X
#     X = 'NI'
#     >>> func()
#     >>> print(X)
#
#
#
# ### sol--> This code will return a "NI" because when we call a function (func()) so inside a function we overwrite  the Global variable X value with the help of the (global) keyword.
#
#
#
#
#
#     5. What about this code—what’s the output, and why?
#     >>> X = 'iNeuron'
#     >>> def func():
#     X = 'NI'
#     def nested():
#     print(X)
#     nested()
#     >>> func()
#     >>> X
#
#
#
# ### sol--> func() will return a "NI" as output because when be call a func() so inside that func we assign a X="NI" then we call our (nested()) function and it will prinnt a X value because X variable  is not aviable it its local scope so it will use her super function(func()) X and print a X value which is "NI".
#
# ### X will print a "iNeuron" because X assign a "Ineuron " globally
#
#
#
#
#     6. How about this code: what is its output in Python 3, and explain?
#
#     >>> def func():
#     X = 'NI'
#     def nested():
#     nonlocal X
#     X = 'Spam'
#     nested()
#     print(X)
#     >>> func()
#
#
#
#
# ### sol--> This Code return a "spam" as a output because when we call a func() then it will go inside a function and assign a "NI" to the variable X="NI" then it will call a Nested() function which is implemented inside her so when we go inside a nested function body it will use a (nonlocal) keyword with X variable which can replace or Overwrite a X value Now X ="iNeuron" so when we print a X variable inside a (func()) so it will print X but now X is Overwrited by her (nested()) function so it will print a overwrited value "Spam".
